# 45  Abbotsford      11/205 Gipps St      1    u   470000.0      S
# 46  Abbotsford        47 Studley St      2    h  1180000.0      S
# 47  Abbotsford          45 Yarra St      3    h  1195000.0     SP
# 48  Abbotsford     200 Nicholson St      2    h  1012500.0      S
# 49  Abbotsford    82/84 Trenerry Cr      2    u   970000.0     SP
#
#           SellerG        Date  Distance  Postcode  ...  Car  Landsize  \
# 0          Biggin   3/12/2016       2.5    3067.0  ...  1.0     202.0
# 1          Biggin   4/02/2016       2.5    3067.0  ...  0.0     156.0
# 2          Biggin   4/03/2017       2.5    3067.0  ...  0.0     134.0
# 3          Biggin   4/03/2017       2.5    3067.0  ...  1.0      94.0
# 4          Nelson   4/06/2016       2.5    3067.0  ...  2.0     120.0
# 5          Jellis   7/05/2016       2.5    3067.0  ...  0.0     181.0
# 6          Nelson   7/05/2016       2.5    3067.0  ...  0.0     245.0
# 7          Nelson   8/10/2016       2.5    3067.0  ...  2.0     256.0
# 8          Jellis   8/10/2016       2.5    3067.0  ...  NaN       NaN
# 9          Jellis   8/10/2016       2.5    3067.0  ...  NaN       NaN
# 10         Biggin   8/10/2016       2.5    3067.0  ...  1.0       0.0
# 11         Biggin   8/10/2016       2.5    3067.0  ...  2.0     220.0
# 12         Dingle   8/10/2016       2.5    3067.0  ...  NaN       NaN
# 13         Biggin  10/12/2016       2.5    3067.0  ...  NaN       NaN
# 14   Purplebricks  10/12/2016       2.5    3067.0  ...  NaN       NaN
# 15         Jellis  12/11/2016       2.5    3067.0  ...  1.0       0.0
# 16         Nelson  12/11/2016       2.5    3067.0  ...  2.0     214.0
# 17         Biggin  12/11/2016       2.5    3067.0  ...  1.0       0.0
# 18         Biggin  12/11/2016       2.5    3067.0  ...  NaN       NaN
# 19         Biggin  12/11/2016       2.5    3067.0  ...  NaN       NaN
# 20         Biggin  13/08/2016       2.5    3067.0  ...  1.0     195.0
# 21           Greg  14/05/2016       2.5    3067.0  ...  1.0       0.0
# 22         Jellis  15/10/2016       2.5    3067.0  ...  2.0     238.0
# 23         Jellis  16/07/2016       2.5    3067.0  ...  1.0     113.0
# 24         Jellis  16/07/2016       2.5    3067.0  ...  NaN       NaN
# 25         LITTLE  16/07/2016       2.5    3067.0  ...  1.0     138.0
# 26        Collins  17/09/2016       2.5    3067.0  ...  0.0     183.0
# 27         Biggin  17/09/2016       2.5    3067.0  ...  1.0     150.0
# 28            Kay  18/03/2017       2.5    3067.0  ...  2.0     780.0
# 29         Beller  18/03/2017       2.5    3067.0  ...  2.0       0.0
# 30         Jellis  18/03/2017       2.5    3067.0  ...  2.0    4290.0
# 31        Collins  18/06/2016       2.5    3067.0  ...  1.0       0.0
# 32         Biggin  18/06/2016       2.5    3067.0  ...  1.0     124.0
# 33       Marshall  19/11/2016       2.5    3067.0  ...  0.0     147.0
# 34         Biggin  19/11/2016       2.5    3067.0  ...  NaN       NaN
# 35  hockingstuart  22/05/2016       2.5    3067.0  ...  NaN       NaN
# 36           Greg  22/08/2016       2.5    3067.0  ...  1.0       0.0
# 45  Northern Metropolitan         4019.0  25529
# 46  Northern Metropolitan         4019.0   8652
# 47  Northern Metropolitan         4019.0  18205
# 48  Northern Metropolitan         4019.0  26620
# 49  Northern Metropolitan         4019.0  23881
#
# [50 rows x 22 columns]

# %%
df.shape
# Out:
# (18373, 22)

# %% [markdown]
# # Выполняем предобработку данных и избавляемся от NaN

# %%
df.isna().mean()
# Out:
# Suburb           0.000000
# Address          0.000000
# Rooms            0.000000
# Type             0.000000
# Price            0.000000
# Method           0.000000
# SellerG          0.000000
# Date             0.000000
# Distance         0.000000
# Postcode         0.000000
# Bedroom2         0.188755
# Bathroom         0.188864
# Car              0.194579
# Landsize         0.260926
# BuildingArea     0.578185
# YearBuilt        0.513199
# CouncilArea      0.000054
# Lattitude        0.181353
# Longtitude       0.181353
# Regionname       0.000054
# Propertycount    0.000054
# id               0.000000
# dtype: float64

# %%
sp = pd.Series(df.columns).tolist()

# %%
sp
# Out:
# ['Suburb',
#  'Address',
#  'Rooms',
#  'Type',
#  'Price',
#  'Method',
#  'SellerG',
#  'Date',
#  'Distance',
#  'Postcode',
#  'Bedroom2',
#  'Bathroom',
#  'Car',
#  'Landsize',
#  'BuildingArea',
#  'YearBuilt',
#  'CouncilArea',
#  'Lattitude',
#  'Longtitude',
#  'Regionname',
#  'Propertycount',
#  'id']

# %%
for i in sp:
    df[i] = df[i].fillna(df[i].mode()[0])

# %%
df.isna().mean()
# Out:
# Suburb           0.0
# Address          0.0
# Rooms            0.0
# Type             0.0
# Price            0.0
# Method           0.0
# SellerG          0.0
# Date             0.0
# Distance         0.0
# Postcode         0.0
# Bedroom2         0.0
# Bathroom         0.0
# Car              0.0
# Landsize         0.0
# BuildingArea     0.0
# YearBuilt        0.0
# CouncilArea      0.0
# Lattitude        0.0
# Longtitude       0.0
# Regionname       0.0
# Propertycount    0.0
# id               0.0
# dtype: float64

# %%
df.shape
# Out:
# (18373, 22)

# %% [markdown]
# # Начинаем сборку модели машинного обучения

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df,train_size=0.6,random_state=42)
val, test = train_test_split(test,train_size=0.5,random_state=42)

# %%
train.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount', 'id'],
#       dtype='object')

# %%
train.select_dtypes(include='object')
# Out:
#                Suburb            Address Type Method    SellerG        Date  \
# 7487         St Kilda  6/22 Charnwood Cr    u     VB     Hodges  28/05/2016
# 14244         Tarneit       4 Welford St    h     SP   Reliance  12/08/2017
# 7621         Sunshine      17 Leonard St    h      S    Douglas  18/06/2016
# 13334      Nunawading      3/7 Lilian St    t      S  Fletchers  27/05/2017
# 9412      Albert Park       21 Finlay St    h      S   Marshall  13/05/2017
# ...               ...                ...  ...    ...        ...         ...
# 11284    Narre Warren      28 Murdoch Av    h     SP    O'Brien   1/07/2017
# 11964        Armadale      504 Orrong Rd    h     VB        Kay  17/06/2017
# 5390          Newport       33 Oxford St    h      S   Williams   7/11/2016
# 860      Balwyn North     237a Balwyn Rd    h     PI    Appleby  16/04/2016
# 15795  West Melbourne   4/593 Spencer St    u      S       MICM   3/09/2017
#
#                      CouncilArea                  Regionname
# 7487   Port Phillip City Council       Southern Metropolitan
# 14244       Wyndham City Council        Western Metropolitan
# 7621       Brimbank City Council        Western Metropolitan
# 13334    Manningham City Council        Eastern Metropolitan
# 9412   Port Phillip City Council       Southern Metropolitan
# ...                          ...                         ...
# 11284         Casey City Council  South-Eastern Metropolitan
# 11964   Stonnington City Council       Southern Metropolitan
# 5390    Hobsons Bay City Council        Western Metropolitan
# 860      Boroondara City Council       Southern Metropolitan
# 15795     Melbourne City Council       Northern Metropolitan
#
# [11023 rows x 8 columns]

# %%
X = ['Suburb', 'Rooms', 'Type', 'Method',
     'Distance', 'Bedroom2', 'Bathroom', 'Car',
       'Landsize', 'BuildingArea', 'YearBuilt', 
     'CouncilArea', 'Regionname', 'Propertycount']

cat_features = ['Suburb','Type','Method','CouncilArea','Regionname']

y = ['Price']

# %%
from catboost import Pool

train_data = Pool(data=train[X],
                  label=train[y],
                  cat_features=cat_features,
                 )

valid_data = Pool(data=val[X],
                  label=val[y],
                  cat_features=cat_features
                 )

# %%
from catboost import CatBoostRegressor

# %%
parameters = {'cat_features': cat_features,
              'eval_metric': 'MAPE',
              'early_stopping_rounds':200,
              'random_seed':42,
              'learning_rate':0.1,
              'verbose':50}

# %%
model = CatBoostRegressor(**parameters)

# %%
model.fit(train_data, eval_set=valid_data)
# Out:
# 0:	learn: 0.5026030	test: 0.4909703	best: 0.4909703 (0)	total: 52.6ms	remaining: 52.5s
# 50:	learn: 0.1886583	test: 0.1821462	best: 0.1821462 (50)	total: 2.82s	remaining: 52.4s
# 100:	learn: 0.1766804	test: 0.1740280	best: 0.1740280 (100)	total: 5.43s	remaining: 48.3s
# 150:	learn: 0.1662582	test: 0.1673131	best: 0.1673131 (150)	total: 8.14s	remaining: 45.8s
# 200:	learn: 0.1603146	test: 0.1638298	best: 0.1638263 (198)	total: 10.9s	remaining: 43.1s
# 250:	learn: 0.1563169	test: 0.1618255	best: 0.1618255 (250)	total: 13.7s	remaining: 40.8s
# 300:	learn: 0.1530121	test: 0.1602397	best: 0.1601861 (297)	total: 16.4s	remaining: 38.2s
# 350:	learn: 0.1500902	test: 0.1589755	best: 0.1589755 (350)	total: 19.2s	remaining: 35.5s
# 400:	learn: 0.1475055	test: 0.1580270	best: 0.1579452 (393)	total: 22s	remaining: 32.9s
# 450:	learn: 0.1456320	test: 0.1574647	best: 0.1574617 (448)	total: 24.7s	remaining: 30.1s
# 500:	learn: 0.1437065	test: 0.1569538	best: 0.1569279 (496)	total: 27.5s	remaining: 27.4s
# 550:	learn: 0.1417599	test: 0.1564818	best: 0.1564818 (550)	total: 30.3s	remaining: 24.7s
# 600:	learn: 0.1402169	test: 0.1561085	best: 0.1561048 (599)	total: 33.1s	remaining: 22s
# 650:	learn: 0.1386183	test: 0.1556238	best: 0.1556047 (649)	total: 35.9s	remaining: 19.2s
# 700:	learn: 0.1372327	test: 0.1553054	best: 0.1553054 (700)	total: 38.7s	remaining: 16.5s
# 750:	learn: 0.1358616	test: 0.1550410	best: 0.1550410 (750)	total: 41.5s	remaining: 13.7s
# 800:	learn: 0.1345779	test: 0.1547256	best: 0.1546965 (787)	total: 44.3s	remaining: 11s
# 850:	learn: 0.1336701	test: 0.1545346	best: 0.1544869 (848)	total: 47s	remaining: 8.23s
# 900:	learn: 0.1326726	test: 0.1544869	best: 0.1544323 (873)	total: 49.8s	remaining: 5.48s
# 950:	learn: 0.1317138	test: 0.1542211	best: 0.1542211 (950)	total: 52.7s	remaining: 2.71s
# 999:	learn: 0.1306655	test: 0.1540521	best: 0.1540001 (974)	total: 55.5s	remaining: 0us
#
# bestTest = 0.1540001191
# bestIteration = 974
#
# Shrink model to first 975 iterations.

# %% [markdown]
# # Добавляем тестовый датасет

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

def error(y_true,y_pred):
  print(mean_absolute_error(y_true,y_pred))
  print(mean_absolute_percentage_error(y_true,y_pred))

# %%
test['price_pred_all'] = model.predict(test[X])

# %%
test
# Out:
#                    Suburb            Address  Rooms Type      Price Method  \
# 4457           Kensington         5 Rigby La      3    t   845000.0      S
# 15951              Epping     10/81 Rufus St      2    u   291000.0      S
# 13988              Eltham    17/1336 Main Rd      4    h   762000.0      S
# 4936         Malvern East   5/25 Clarence St      1    u   373000.0     SP
# 2896          Elsternwick   3/477 Kooyong Rd      3    t  1071000.0      S
# ...                   ...                ...    ...  ...        ...    ...
# 4169   Heidelberg Heights   522 Waterdale Rd      2    h   526000.0      S
# 2012              Burwood  1/392 Burwood Hwy      3    t   752000.0      S
# 3509            Glen Iris       1/46 Iris Rd      3    h  1222000.0      S
# 176            Alphington      10 Bennett St      4    h  1830000.0      S
# 2856            Doncaster       8 Winters Wy      3    h  1170500.0      S
#
#              SellerG        Date  Distance  Postcode  ...  Landsize  \
# 4457          Nelson   4/03/2017       4.2    3031.0  ...     132.0
# 15951            HAR   9/09/2017      19.6    3076.0  ...     161.0
# 13988         Jellis  12/08/2017      18.0    3095.0  ...     573.0
# 4936   hockingstuart  24/09/2016      11.2    3145.0  ...       0.0
# 2896          Biggin  16/04/2016       8.5    3185.0  ...     179.0
# ...              ...         ...       ...       ...  ...       ...
# 4169           Barry  27/06/2016      10.5    3081.0  ...     310.0
# 2012          Allens  17/09/2016      11.7    3125.0  ...     217.0
# 3509        Marshall   8/10/2016       9.2    3146.0  ...     215.0
# 176           Nelson  19/11/2016       6.4    3078.0  ...     606.0
# 2856           Barry  30/07/2016      13.9    3108.0  ...       0.0
#
#        BuildingArea  YearBuilt               CouncilArea  Lattitude  \
# 4457          105.0     1970.0    Melbourne City Council  -37.79070
# 15951         120.0     1970.0   Whittlesea City Council  -37.64888
# 13988         180.0     1980.0      Banyule City Council  -37.70477
# 4936           38.0     1965.0  Stonnington City Council  -37.87280
# 2896          125.0     2000.0    Glen Eira City Council  -37.89610
# ...             ...        ...                       ...        ...
# 4169          120.0     1994.0      Banyule City Council  -37.73890
# 2012          120.0     1993.0       Monash City Council  -37.85220
# 3509          120.0     1970.0   Boroondara City Council  -37.85000
# 176           112.0     1970.0      Darebin City Council  -37.77430
# 2856          120.0     1970.0   Manningham City Council  -37.83610
#
#        Longtitude             Regionname  Propertycount     id price_pred_all
# 4457    144.92470  Northern Metropolitan         5263.0  23921   8.510710e+05
# 15951   145.02313  Northern Metropolitan        10926.0  29993   3.844898e+05
# 13988   145.16552   Eastern Metropolitan         6990.0  18337   8.170295e+05
# 4936    145.04170  Southern Metropolitan         8801.0   2406   3.257161e+05
# 2896    145.01250  Southern Metropolitan         4898.0  19596   1.137193e+06
# ...           ...                    ...            ...    ...            ...
# 4169    145.04860   Eastern Metropolitan         2947.0  24146   6.454909e+05
# 2012    145.13120  Southern Metropolitan         5678.0  17971   9.602469e+05
# 3509    145.05700  Southern Metropolitan        10412.0  27335   1.175615e+06
# 176     145.03160  Northern Metropolitan         2211.0  14164   1.670551e+06
# 2856    144.99660   Eastern Metropolitan         9028.0  18167   1.093943e+06
#
# [3675 rows x 23 columns]

# %%
error(test['Price'],test['price_pred_all'])
# Out:
# 168750.94113942716
# 0.1605833242629532

# %% [markdown]
# # Обучаемся на всех данных

# %%
len(train)
# Out:
# 11023

# %%
len(val)
# Out:
# 3675

# %%
len(train) + len(val)
# Out:
# 14698

# %%
train_full = pd.concat([train,val])

# %%
parameters = {'cat_features': cat_features,
              'eval_metric': 'MAPE',
              'random_seed':42,
              'learning_rate':0.04,
              'verbose':100}

model = CatBoostRegressor(**parameters)

# %%
train_full = Pool(data=train_full[X],
                  label=train_full[y],
                  cat_features=cat_features,
                 )

# %%
model.fit(train_full)
# Out:
# 0:	learn: 0.5204876	total: 58.4ms	remaining: 58.4s
# 100:	learn: 0.1926408	total: 5.66s	remaining: 50.4s
# 200:	learn: 0.1760499	total: 11.4s	remaining: 45.5s
# 300:	learn: 0.1689247	total: 17.1s	remaining: 39.7s
# 400:	learn: 0.1634348	total: 22.8s	remaining: 34s
# 500:	learn: 0.1598078	total: 28.4s	remaining: 28.3s
# 600:	learn: 0.1573201	total: 34.1s	remaining: 22.7s
# 700:	learn: 0.1547240	total: 39.9s	remaining: 17s
# 800:	learn: 0.1522955	total: 45.6s	remaining: 11.3s
# 900:	learn: 0.1501259	total: 51.3s	remaining: 5.63s
# 999:	learn: 0.1484678	total: 57.1s	remaining: 0us

# %%
test['price_pred_all_features_and_data'] = model.predict(test[X])

# %%
error(test['Price'],test['price_pred_all_features_and_data'])
# Out:
# 170372.46591961218
# 0.16350029698754875

# %% [markdown]
# # Загружаем датасет для оценки

# %%
test_new = pd.read_csv('D:/ds/leopard-challenge/test.csv')

# %%
test_new.shape
# Out:
# (8818, 21)

# %%
test_new.isna().mean()
# Out:
# Suburb           0.000000
# Address          0.000000
# Rooms            0.000000
# Type             0.000000
# Method           0.000000
# SellerG          0.000000
# Date             0.000000
# Distance         0.000113
# Postcode         0.000113
# Bedroom2         0.335677
# Bathroom         0.336131
# Car              0.366977
# Landsize         0.504990
# BuildingArea     0.673169
# YearBuilt        0.647086
# CouncilArea      0.000227
# Lattitude        0.330007
# Longtitude       0.330007
# Regionname       0.000227
# Propertycount    0.000227
# id               0.000000
# dtype: float64

# %%
sp_test = pd.Series(test_new.columns).tolist()

for i in sp_test:
    test_new[i] = test_new[i].fillna(test_new[i].mode()[0])

# %%
test_new.isna().mean()
# Out:
# Suburb           0.0
# Address          0.0
# Rooms            0.0
# Type             0.0
# Method           0.0
# SellerG          0.0
# Date             0.0
# Distance         0.0
# Postcode         0.0
# Bedroom2         0.0
# Bathroom         0.0
# Car              0.0
# Landsize         0.0
# BuildingArea     0.0
# YearBuilt        0.0
# CouncilArea      0.0
# Lattitude        0.0
# Longtitude       0.0
# Regionname       0.0
# Propertycount    0.0
# id               0.0
# dtype: float64

# %%
test_new.shape
# Out:
# (8818, 21)

# %%
test_new.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Method', 'SellerG', 'Date',
#        'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car', 'Landsize',
#        'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude', 'Longtitude',
#        'Regionname', 'Propertycount', 'id'],
#       dtype='object')

# %%
test_new['Price'] = model.predict(test_new[X])

# %%
test_new.head()
# Out:
#          Suburb          Address  Rooms Type Method SellerG       Date  \
# 0    Abbotsford  513/6 Acacia Pl      3    u      S  Dingle  7/10/2017
# 1    Abbotsford    60 Charles St      3    h      S  Jellis  7/10/2017
# 2    Abbotsford    38 Studley St      3    h      S  Nelson  7/10/2017
# 3  Airport West     18 Glenys Av      3    h      S   Raine  7/10/2017
# 4  Airport West     35 Thomas St      3    h      S  Nelson  7/10/2017
#
#    Distance  Postcode  Bedroom2  ...  Landsize  BuildingArea  YearBuilt  \
# 0       3.0    3067.0       3.0  ...     650.0         140.0     1970.0
# 1       3.0    3067.0       3.0  ...     192.0         109.0     1900.0
# 2       3.0    3067.0       3.0  ...     159.0          93.0     1890.0
# 3      10.4    3042.0       3.0  ...     536.0         108.0     1980.0
# 4      10.4    3042.0       3.0  ...     650.0         130.0     2009.0
#
#                   CouncilArea  Lattitude Longtitude             Regionname  \
# 0          Yarra City Council  -37.78290  145.02513  Northern Metropolitan
# 1          Yarra City Council  -37.80792  144.99508  Northern Metropolitan
# 2          Yarra City Council  -37.80124  144.99459  Northern Metropolitan
# 3  Moonee Valley City Council  -37.72285  144.87539   Western Metropolitan
# 4  Moonee Valley City Council  -37.71754  144.87704   Western Metropolitan
#
#    Propertycount     id         Price
# 0         4019.0  30130  1.199620e+06
# 1         4019.0  18311  1.435800e+06
# 2         4019.0  18934  1.286098e+06
# 3         3464.0   1824  7.952290e+05
# 4         3464.0  31339  8.587496e+05
#
# [5 rows x 22 columns]

# %%
test_new[['id','Price']].to_csv('my_sub.csv', index=False)

# %%
test_ = pd.read_csv('D:/ds/leopard-challenge/my_sub.csv')

# %%
test_
# Out:
#          id         Price
# 0     30130  1.199620e+06
# 1     18311  1.435800e+06
# 2     18934  1.286098e+06
# 3      1824  7.952290e+05
# 4     31339  8.587496e+05
# ...     ...           ...
# 8813  11120  1.264263e+06
# 8814   3950  7.401826e+05
# 8815   2209  6.767973e+05
# 8816  23872  1.286123e+06
# 8817   8572  8.266889e+05
#
# [8818 rows x 2 columns]
